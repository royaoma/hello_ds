# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
d = {'age': [30,35,38,39,42,46,50,53], 'salary': [800,900,860,950,990,850,2000,960]}
df = pd.DataFrame(data=d)

# %%
g = sns.relplot(data=df, x="age", y="salary")
g.ax.axline(xy1=(10, 2), slope=.2, color="b", dashes=(5, 2))

# %%
cars = pd.read_csv('BMW X3.csv')
df = pd.DataFrame(data=cars)

#f, axs = plt.subplots(1, 2, figsize=(8, 4), gridspec_kw=dict(width_ratios=[4, 3]))
#sns.scatterplot(data=cars, x="Km", y="NOK", hue="Year", ax=axs[0])
#sns.histplot(data=cars, x="Year", hue="Year", shrink=.8, alpha=.8, legend=False, ax=axs[1])
#f.tight_layout()

sns.jointplot(data=cars, x="Km", y="NOK", hue="Year")

# %%
sns.pairplot(data=cars, hue="Year")

# %%
import yfinance as yf
import pendulum
import matplotlib.pyplot as plt

# %%
price_history = yf.Ticker('NKE').history(period='1y', # valid periods: 1d,5d,1mo,3mo,6mo,1y,2y,5y,10y,ytd,max
                                   interval='1d', # valid intervals: 1m,2m,5m,15m,30m,60m,90m,1h,1d,5d,1wk,1mo,3mo
                                   actions=False)
time_series = list(price_history['Open'])
dt_list = [pendulum.parse(str(dt)).float_timestamp for dt in list(price_history.index)]
plt.style.use('dark_background')
plt.plot(dt_list, time_series, linewidth=2)

# %%
print(price_history)
# Out:
#                   Open        High         Low       Close    Volume
# Date
# 2021-10-11  150.565316  152.150309  148.653399  148.871338   5551200
# 2021-10-12  150.991292  152.160239  149.881795  151.912582   7408600
# 2021-10-13  152.873509  155.201473  151.724379  154.834946   8456300
# 2021-10-14  156.697298  156.974688  154.785396  155.667053   6024500
# 2021-10-15  156.320862  156.845893  155.092480  156.528885   5532100
# ...                ...         ...         ...         ...       ...
# 2022-10-04   87.699997   89.070000   87.110001   88.639999  15114800
# 2022-10-05   87.489998   91.699997   87.150002   91.099998  12732700
# 2022-10-06   90.489998   92.639999   89.809998   90.169998   9951900
# 2022-10-07   88.540001   88.760002   86.690002   87.160004   8552100
# 2022-10-10   87.760002   87.779999   85.070000   86.690002   7253616
#
# [252 rows x 5 columns]

# %%
price_history['Close']
# Out:
# Date
# 2021-10-11    148.871338
# 2021-10-12    151.912582
# 2021-10-13    154.834946
# 2021-10-14    155.667053
# 2021-10-15    156.528885
#                  ...
# 2022-10-04     88.639999
# 2022-10-05     91.099998
# 2022-10-06     90.169998
# 2022-10-07     87.160004
# 2022-10-10     86.690002
# Name: Close, Length: 252, dtype: float64

# %%
price_history_SnP500 = yf.Ticker('^GSPC').history(period='1y', # valid periods: 1d,5d,1mo,3mo,6mo,1y,2y,5y,10y,ytd,max
                                   interval='1d', # valid intervals: 1m,2m,5m,15m,30m,60m,90m,1h,1d,5d,1wk,1mo,3mo
                                   actions=False)
time_series = list(price_history_SnP500['Open'])
dt_list = [pendulum.parse(str(dt)).float_timestamp for dt in list(price_history_SnP500.index)]
plt.style.use('dark_background')
plt.plot(dt_list, time_series, linewidth=2)

# %%
print(price_history['Close']/2)
print(price_history_SnP500['Close']/2)
# Out:
# Date
# 2021-10-15    78.264435
# 2021-10-18    78.967781
# 2021-10-19    78.170341
# 2021-10-20    78.482384
# 2021-10-21    80.329903
#                 ...
# 2022-10-10    43.345001
# 2022-10-11    43.994999
# 2022-10-12    44.255001
# 2022-10-13    44.779999
# 2022-10-14    43.775002
# Name: Close, Length: 252, dtype: float64
# Date
# 2021-10-15    2235.685059
# 2021-10-18    2243.229980
# 2021-10-19    2259.814941
# 2021-10-20    2268.094971
# 2021-10-21    2274.889893
#                  ...
# 2022-10-10    1806.194946
# 2022-10-11    1794.420044
# 2022-10-12    1788.515015
# 2022-10-13    1834.954956
# 2022-10-14    1791.535034
# Name: Close, Length: 252, dtype: float64

# %%
price_history['Close'].values
#price_history_SnP500['High'].values
# Out:
# array([156.52886963, 157.93556213, 156.34068298, 156.96476746,
#        160.6598053 , 161.94761658, 162.68067932, 162.25469971,
#        160.82821655, 162.91845703, 165.72189331, 164.77090454,
#        166.2568512 , 170.8830719 , 173.79551697, 175.84609985,
#        170.23918152, 172.19070435, 166.68281555, 165.40492249,
#        167.50505066, 167.26730347, 170.21936035, 170.13020325,
#        169.74386597, 173.24078369, 172.60676575, 170.53634644,
#        170.41748047, 166.44506836, 168.27770996, 167.65362549,
#        165.13743591, 168.40649414, 168.94735718, 167.62745667,
#        169.98937988, 168.95730591, 166.82362366, 167.77632141,
#        165.57318115, 164.144104  , 162.65548706, 161.48445129,
#        160.13479614, 155.78804016, 165.36477661, 164.18380737,
#        164.4120636 , 166.30755615, 165.15637207, 167.49845886,
#        166.21824646, 165.40447998, 163.41966248, 165.12658691,
#        161.01803589, 159.81721497, 155.77812195, 149.29769897,
# ...
